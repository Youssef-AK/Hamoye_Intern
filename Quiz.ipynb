# %%
import pandas as pd
import numpy as np
from scipy.stats import kurtosis, skew

# %%
url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv?row=true'
df = pd.read_csv(url, error_bad_lines=False)

# %%
df.describe(include= 'all')
# Out:
#                       record_id  utility_id_ferc1   report_year  \
# count                     29523      29523.000000  29523.000000
# unique                    29523               NaN           NaN
# top     f1_fuel_2014_12_163_0_1               NaN           NaN
# freq                          1               NaN           NaN
# mean                        NaN        118.601836   2005.806050
# std                         NaN         74.178353      7.025483
# min                         NaN          1.000000   1994.000000
# 25%                         NaN         55.000000   2000.000000
# 50%                         NaN        122.000000   2006.000000
# 75%                         NaN        176.000000   2012.000000
# max                         NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
df['fuel_unit'].unique()
# Out:
# array(['ton', 'mcf', 'kgU', 'bbl', 'gramsU', nan, 'mwdth', 'mmbtu',
#        'mwhth', 'gal'], dtype=object)

# %%
# Quiz Test
df['fuel_unit'].value_counts().sum()
# Out:
# 29343

# %%
miss = 180 / 29343
precent = miss * 100
print(precent)
# Out:
# 0.6134342091810653

# %%
df.groupby('fuel_type_code_pudl')['fuel_cost_per_unit_burned'].count().sum()
# Out:
# 29523

# %%
skew(df['fuel_qty_burned'], bias= False)
# Out:
# 15.8514954691095

# %%
kurtosis(df['fuel_qty_burned'], bias = False)
# Out:
# 651.3694501337731

# %%
df.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
year98 = df[df['report_year'] == 1998]
year94 = df[df['report_year'] == 1994]

coal_type = df[df['fuel_type_code_pudl'] == 'coal']

# %%
(df[df['report_year'] == 1998]).sum()
# Out:
# record_id                       f1_fuel_1998_12_1_0_7f1_fuel_1998_12_1_0_10f1_...
# utility_id_ferc1                                                           121599
# report_year                                                               2211786
# plant_name_ferc1                rockport total aegrockport total plantunits 1 ...
# fuel_type_code_pudl             coalcoalcoalgascoalgascoalcoalcoalcoalcoaloilc...
# fuel_qty_burned                                                      3617070075.0
# fuel_mmbtu_per_unit                                                  11850.394701
# fuel_cost_per_unit_burned                                              140238.656
# fuel_cost_per_unit_delivered                                           317879.943
# fuel_cost_per_mmbtu                                                    3072.87907
# dtype: object

# %%
perc94 = 263292.115 / 6159945.342
perc98 = 140238.656 / 6159945.342
print(perc94 * 100)
print(perc98 * 100)
print(perc94 - perc98)
# Out:
# 4.2742605718399895
# 2.276621759024692
# 0.019976388128152972

# %%
df['fuel_cost_per_unit_burned'].sum()
# Out:
# 6159945.342999999

# %%
df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
(df['fuel_cost_per_unit_delivered'].max())
# Out:
# 7964521.0
